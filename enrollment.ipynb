# %%
import pandas as pd
import numpy as np
import matplotlib.pyplot as plt
import sklearn
from pylab import rcParams
from sklearn.preprocessing import scale
from sklearn.linear_model import LinearRegression
# %matplotlib inline
rcParams['figure.figsize'] = 13,7
import seaborn as sb
sb.set_style('whitegrid')
from collections import Counter

# %%
df = pd.read_csv('C:/Users/Administrator/test/ML/Machine-Learning/enrollment_forecast.csv')
df
# Out:
#     year   roll  unem  hgrad   inc
# 0      1   5501   8.1   9552  1923
# 1      2   5945   7.0   9680  1961
# 2      3   6629   7.3   9731  1979
# 3      4   7556   7.5  11666  2030
# 4      5   8716   7.0  14675  2112
# 5      6   9369   6.4  15265  2192
# 6      7   9920   6.5  15484  2235
# 7      8  10167   6.4  15723  2351
# 8      9  11084   6.3  16501  2411
# 9     10  12504   7.7  16890  2475
# 10    11  13746   8.2  17203  2524
# 11    12  13656   7.5  17707  2674
# 12    13  13850   7.4  18108  2833
# 13    14  14145   8.2  18266  2863
# 14    15  14888  10.1  19308  2839
# 15    16  14991   9.2  18224  2898
# 16    17  14836   7.7  18997  3123
# 17    18  14478   5.7  19505  3195
# 18    19  14539   6.5  19800  3239
# 19    20  14395   7.5  19546  3129
# 20    21  14599   7.3  19117  3100
# 21    22  14969   9.2  18774  3008
# 22    23  15107  10.1  17813  2983
# 23    24  14831   7.5  17304  3069
# 24    25  15081   8.8  16756  3151
# 25    26  15127   9.1  16749  3127
# ...

# %%
sb.pairplot(df)

# %%
print(df.corr())
# Out:
#            year      roll      unem     hgrad       inc
# year   1.000000  0.900934  0.378305  0.670300  0.944287
# roll   0.900934  1.000000  0.391344  0.890294  0.949876
# unem   0.378305  0.391344  1.000000  0.177376  0.282310
# hgrad  0.670300  0.890294  0.177376  1.000000  0.820089
# inc    0.944287  0.949876  0.282310  0.820089  1.000000

# %%
df_data = df[['unem', 'hgrad']].values
df_target = df[['roll']].values
df_data_names = ['unem', 'hgrad']
X,y = scale(df_data), df_target

# %%
missingValues = y == np.NAN
y[missingValues == True]
# Out:
# array([], dtype=int64)

# %%
missingValues = X == np.NAN
X[missingValues == True]
# Out:
# array([], dtype=float64)

# %%
LinReg = LinearRegression(normalize=True)
LinReg.fit(X,y)
print('Score for Unem and Hgrad wrt roll = ',LinReg.score(X,y))
# Out:
# Score for Unem and Hgrad wrt roll =  0.8488812666133723

# %%
df_data = df[['roll', 'hgrad']].values
df_target = df[['inc']].values
df_data_names = ['roll', 'hgrad']
X,y = scale(df_data), df_target

# %%
missingValues = X == np.NAN
X[missingValues == True]
# Out:
# array([], dtype=float64)

# %%
missingValues = y == np.NAN
y[missingValues == True]
# Out:
# array([], dtype=int64)

# %%
LinReg = LinearRegression(normalize=True)
LinReg.fit(X,y)
print('Score for Roll and Hgrad wrt Inc = ',LinReg.score(X,y))
# Out:
# Score for Roll and Hgrad wrt Inc =  0.905418954078825

# %%
df_data = df[['roll']].values
df_target = df[['hgrad']].values
df_data_names = ['roll']
X,y = scale(df_data), df_target

# %%
missingValues = X == np.NAN
X[missingValues == True]
# Out:
# array([], dtype=float64)

# %%
missingValues = y == np.NAN
y[missingValues == True]
# Out:
# array([], dtype=int64)

# %%
LinReg = LinearRegression(normalize=True)
LinReg.fit(X,y)
print('Score for Roll and Hgrad  = ',LinReg.score(X,y))
# Out:
# Score for Roll and Hgrad  =  0.7926231779441607
